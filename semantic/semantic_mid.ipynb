# %%
# требование из СП 59.13330 

'''
5.2.1 На стоянке (парковке) транспортных средств личного пользования, 
расположенной на участке около здания организации сферы услуг или внутри этого здания, 
следует выделять 10 % машино-мест (но не менее одного места) для людей с инвалидностью, 

в том числе количество специализированных расширенных машино-мест для транспортных средств инвалидов, передвигающихся на кресле-коляске, определять расчетом, при числе мест: 
- до 100 включительно……. 5 %, но не менее одного места;
- от 101 до 200…………. 5 мест и дополнительно 3 % от количества мест свыше 100;
- от 201 до 500…………. 8 мест и дополнительно 2 % от количества мест свыше 200;
- 501 и более………. 14 мест и дополнительно 1 % от количества мест свыше 500.


Каждое выделяемое машино-место должно обозначаться дорожной разметкой и, кроме того, на участке около здания – дорожными знаками, внутри зданий – знаком доступности, 
выполняемым на вертикальной поверхности (стене, стойке и т.п.) на высоте от 1,5 до 2,0 м.
'''
# Out:
# '\n5.2.1 На стоянке (парковке) транспортных средств личного пользования, \n\nрасположенной на участке около здания организации сферы услуг или внутри этого здания, \n\nследует выделять 10 % машино-мест (но не менее одного места) для людей с инвалидностью, \n\nв том числе количество специализированных расширенных машино-мест для транспортных средств инвалидов, передвигающихся на кресле-коляске, определять расчетом, при числе мест: \n- до 100 включительно……. 5 %, но не менее одного места;\n- от 101 до 200…………. 5 мест и дополнительно 3 % от количества мест свыше 100;\n- от 201 до 500…………. 8 мест и дополнительно 2 % от количества мест свыше 200;\n- 501 и более………. 14 мест и дополнительно 1 % от количества мест свыше 500.\n\n\n\nКаждое выделяемое машино-место должно обозначаться дорожной разметкой и, кроме того, на участке около здания – дорожными знаками, внутри зданий – знаком доступности, \nвыполняемым на вертикальной поверхности (стене, стойке и т.п.) на высоте от 1,5 до 2,0 м.\n'

# %%
Construction = {"здание" : "здание организации сферы услуг"}

Spatial_1 = {"помещение, зона" : "стоянка (парковка) транспортных средств личного пользования"}

condition_place_1 = {"расположение стоянка (парковка) транспортных средств личного пользования" : "внутри здание организации сферы услуг"}
condition_place_2 = {"расположение стоянка (парковка) транспортных средств личного пользования" : "около здание организации сферы услуг"}

condition_1 = {"количество машиномест для людей с инвалидностью" : "определяется как фиксированное число обязательных мест в зависимости от общего количества машиномест"}
condition_2 = {"количество машиномест для людей с инвалидностью" : "определяется как процентное отношение от общего количества машиномест"}

condition_3 = {"количество специализированных расширенных машино-мест" : "определяется как фиксированное число обязательных мест в зависимости от общего количества машиномест"}
condition_4 = {"количество специализированных расширенных машино-мест" : "определяется как процентное отношение от общего количества машиномест"}
condition_5 = {"количество специализированных расширенных машино-мест" : "определяется как процентное отношение от общего количества машиномест мест свыше 100"}
condition_6 = {"количество специализированных расширенных машино-мест" : "определяется как процентное отношение от общего количества машиномест мест свыше 200"}
condition_7 = {"количество специализированных расширенных машино-мест" : "определяется как процентное отношение от общего количества машиномест мест свыше 500"}

rule_1 = {"количество машиномест для людей с инвалидностью" : "не менее одного места"}
rule_2 = {"количество машиномест для людей с инвалидностью" : "не менее 10% от общего количества машиномест"}

rule_3 = {"количество специализированных расширенных машино-мест" : "не менее одного места"}
rule_4 = {"количество специализированных расширенных машино-мест" : "5% от общего количества машиномест"}
rule_5 = {"количество специализированных расширенных машино-мест" : "5 мест"}
rule_6 = {"количество специализированных расширенных машино-мест" : "3% от количества мест свыше 100"}
rule_7 = {"количество специализированных расширенных машино-мест" : "8 мест"}
rule_8 = {"количество специализированных расширенных машино-мест" : "2% от количества мест свыше 200"}
rule_9 = {"количество специализированных расширенных машино-мест" : "14 мест"}
rule_10 = {"количество специализированных расширенных машино-мест" : "1% от количества мест свыше 500"}

# %%
class Building():
    def __init__(self, construction):
        self.construction = construction



class Object_for_check():
    def __init__(self, name, place, number_parking_spaces, number_parking_spaces_disable, number_parking_spaces_disable_with_wheelchair) :
        self.name = name
        self.place = place
        self.number_parking_spaces = number_parking_spaces
        self.number_parking_spaces_disable = number_parking_spaces_disable
        self.number_parking_spaces_disable_with_wheelchair = number_parking_spaces_disable_with_wheelchair

# %%
building_0 = Building(
    construction = "здание организации сферы услуг"
                      
                      )


object_0 = Object_for_check(
    name = "стоянка (парковка) транспортных средств личного пользования",
    place = "внутри здание организации сферы услуг",
    number_parking_spaces = 150,
    number_parking_spaces_disable = 10,
    number_parking_spaces_disable_with_wheelchair = 1
                      
                      )

# %%
def check_disabled_parking_spaces(building, object_for_check):
    if (building.construction == "здание организации сферы услуг" and
        object_for_check.name == "стоянка (парковка) транспортных средств личного пользования" and
        (object_for_check.place == "внутри здание организации сферы услуг" or
         object_for_check.place == "около здание организации сферы услуг")
        ):

            if object_for_check.number_parking_spaces_disable < 1:
                print(f"проверка 1 - Ошибка!" +
                        f"количество машиномест для людей с инвалидностью {condition_1["количество машиномест для людей с инвалидностью"]}"+
                        f"количество машиномест для людей с инвалидностью {rule_1["количество машиномест для людей с инвалидностью"]}"
                        )
            else:
                print(f"проверка 1 - Успешно для количества машиномест для людей с инвалидностью прошла успешно")

            if object_for_check.number_parking_spaces_disable < object_for_check.number_parking_spaces * 0.1:
                print("проверка 2 - Ошибка!" +
                            f"количество машиномест для людей с инвалидностью {condition_2["количество машиномест для людей с инвалидностью"]}" +
                            f"{rule_2["количество машиномест для людей с инвалидностью"]}"
                )
            else:
                print(f"проверка 2 - Успешно для количества машиномест для людей с инвалидностью прошла успешно")

            
            if object_for_check.number_parking_spaces <= 100:
                if object_for_check.number_parking_spaces_disable_with_wheelchair < 1:
                    print(f"проверка 3 - Ошибка!" +
                          f"количество спец машиномест для людей с инвалидностью {condition_3["количество специализированных расширенных машино-мест"]}" +
                            f"{rule_3["количество специализированных расширенных машино-мест"]}"
                          )
                else:
                    print(f"проверка 3 - Успешно для количества спец машиномест для людей с инвалидностью прошли успешно")

                if object_for_check.number_parking_spaces_disable_with_wheelchair < object_for_check.number_parking_spaces * 0.05:
                    print("проверка 4 - Ошибка!" +
                              f"количество спец машиномест для людей с инвалидностью {condition_4["количество специализированных расширенных машино-мест"]} - "+
                                f"{rule_4["количество специализированных расширенных машино-мест"]}"
                              )
                else:
                    print(f"проверка 4 - Успешно для количества спец машиномест для людей с инвалидностью прошли успешно")


            if object_for_check.number_parking_spaces > 100 and object_for_check.number_parking_spaces <= 200:

                if object_for_check.number_parking_spaces_disable_with_wheelchair < ((object_for_check.number_parking_spaces - 100) * 0.03) + 5:
                    print("проверка 5 - Ошибка!" +
                              f"количество спец машиномест для людей с инвалидностью {condition_2["количество машиномест для людей с инвалидностью"]}")
                else:
                    print(f"проверка 5 - Успешно для количества спец машиномест для людей с инвалидностью прошли успешно")
    

#- от 101 до 200…………. 5 мест и дополнительно 3 % от количества мест свыше 100;

# %%
check_disabled_parking_spaces(building_0, object_0)
# Out:
# проверка 1 - Успешно для количества машиномест для людей с инвалидностью прошла успешно
# проверка 2 - Ошибка!количество машиномест для людей с инвалидностью определяется как процентное отношение от общего количества машиноместне менее 10% от общего количества машиномест
# проверка 5 - Успешно для количества спец машиномест для людей с инвалидностью прошли успешно
# проверка 6 - Ошибка!количество спец машиномест для людей с инвалидностью определяется как процентное отношение от общего количества машиномест

# %%
service_organization_ksi = "здание организации сферы услуг"
parking_lot_ksi = "стоянка (парковка) транспортных средств личного пользования"

parking_spaces_ksi = "машино-место"
disabled_parking_spaces_ksi = "машино-место для людей с инвалидностью"
wheelchair_parking_spaces_ksi = "специализированное расширенное машино-мест для транспортных средств инвалидов, передвигающихся на кресле-коляске"
marking_ksi = "дорожная разметка"
signs_ksi = "дорожный знак"
accessibility_sign_ksi = "знак доступности"
vertical_surface_ksi = "вертикальная поверхность (стене, стойке и т.п.)"
height_range_ksi = "на высоте от 1,5 до 2,0 м"
