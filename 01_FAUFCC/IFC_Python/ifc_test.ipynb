# %%
import ifcopenshell

# %%
from ifc_loader import IFCLoader
from ifc_element_inspector import IFCElementInspector
from ifc_analyzer import IFCAnalyzer
from ifc_dataset_builder import IFCDatasetBuilder

# %%
class IFCLoader:
    def __init__(self, file_path: str):
        self.file_path = file_path
        self.model = None

    def load(self):
        self.model = ifcopenshell.open(self.file_path)
        return self.model

    def reload(self):
        return self.load()

# %%
loader = IFCLoader("data/2025_01_AR.ifc")
model = loader.load()

builder = IFCDatasetBuilder(model)
dataset = builder.build()

analyzer = IFCAnalyzer(dataset)
inspector = IFCElementInspector(dataset)

# %%
# Показать сводку
analyzer.print_summary()
# Out:
# 📊 Общая сводка по всем категориям:
# Architecture: 70 элементов
# Structure: 6 элементов
# Metal: 244 элементов

# %%
analyzer.print_summary("architecture")
# Out:
# 📂 Сводка по категории 'ARCHITECTURE':
# • Spaces: 4 шт.
# • Walls: 33 шт.
# • Doors: 16 шт.
# • Windows: 0 шт.
# • Slabs: 6 шт.
# • Stairs: 2 шт.
# • Railings: 2 шт.
# • Coverings: 0 шт.
# • Facades: 7 шт.

# %%
# Показать все двери архитектуры
analyzer.print_elements("architecture", "doors")
# Out:
# 🔍 Элементы 'doors' из категории 'architecture':
# - AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974 [GUID: 34MLEKJFT2ifDJcPAg7Kdz]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:486634 [GUID: 34MLEKJFT2ifDJcPAg7KDv]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489130 [GUID: 3at$GBZPL3SxpFATHfZg8U]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489375 [GUID: 3at$GBZPL3SxpFATHfZgCh]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489453 [GUID: 3at$GBZPL3SxpFATHfZgDP]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489662 [GUID: 3at$GBZPL3SxpFATHfZgmA]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489663 [GUID: 3at$GBZPL3SxpFATHfZgmB]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489664 [GUID: 3at$GBZPL3SxpFATHfZgnq]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489670 [GUID: 3at$GBZPL3SxpFATHfZgno]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489671 [GUID: 3at$GBZPL3SxpFATHfZgnp]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489672 [GUID: 3at$GBZPL3SxpFATHfZgny]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:490057 [GUID: 3at$GBZPL3SxpFATHfZgxz]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:491206 [GUID: 3at$GBZPL3SxpFATHfZgfo]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:491210 [GUID: 3at$GBZPL3SxpFATHfZgf_]
# - AC_Дверь_Двупольная_Стальная:1360х2080h Н О Л:492129 [GUID: 3y00uNPof8qhaDFLl2ZQLh]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:492952 [GUID: 3y00uNPof8qhaDFLl2ZQAI]

# %%
# Печатаем все параметры всех помещений
analyzer.print_element_properties("architecture", "spaces")
# Out:
# 🔍 Свойства элемента типа 'spaces' (первый из 4):
#
# 📄 Основные поля IFC:
# • Name: 1
# • LongName: Cafe
# • GlobalId: 1qn_HvrIf1nxexJJxrV$h0
# • PredefinedType: NOTDEFINED
#
# 🧩 Свойства из PropertySet-ов:
#
# 📦 Pset_SpaceCommon
# • IsExternal: False
# • Reference: Cafe 1
#
# 📦 Pset_SpaceHeaterTypeCommon
# • Reference: Cafe 1
#
# 📦 В_Полы-помещения-02_Заполнение типа пола
# • Уровень: Этаж 01
# • Номер: 1
# • Имя: Cafe
#
# 📦 В_Полы-помещения-03_Имена помещений по типам пола
# • Имя: Cafe
#
# 📦 В_Полы-помещения-03_Номера помещений по типам пола
# • Номер: 1
#
# 📦 В_Отделка-помещения-02_Заполнение данных
# • Номер: 1
# • Имя: Cafe
# • Полная высота: 0.026246719160104987
#
# 📦 О_АР_Ведомость отделки помещений_Имя
# • Наименование или номер помещения: Cafe
#
# 📦 О_АР_Ведомость отделки помещений_Номер
# • Наименование или номер помещения: 1
#
# 📦 О_АР_01 Этаж_Экспликация помещений_2 знака
# • Номер помеще- ния: 1
# • Наименование: Cafe
#
# 📦 В_Помещения_Заполнение данных
# • Полная высота: 0.026246719160104987
# • Уровень: Этаж 01
# • Номер: 1
# • Имя: Cafe
#
# 📦 О_АР_01 Этаж_Квартиры_1 знак
# • Наименование: Cafe
#
# 📦 В_Помещения_Этаж
# • Уровень: Этаж 01
#
# 📦 В_Квартиры-00-1_Проверка номеров квартир
# • Имя: Cafe
#
# 📦 О_АР_01 Этаж_Экспликация помещений_1 знак
# • Номер помеще- ния: 1
# • Наименование: Cafe
#
# 📦 О_АР_01 Этаж_Квартиры_2 знака
# • Наименование: Cafe
#
# 📦 Other
# • Category: Rooms
# • Phase Id: 3
#
# 📦 Constraints
# • Base Offset: 0.0
# • Level: Этаж 01
# • Limit Offset: 0.026246719160104987
# • Upper Limit: Этаж 01
#
# 📦 Dimensions
# • Area: 55.74698385820489
# • Computation Height: 0.0
# • Perimeter: 33604.51155511417
# • Unbounded Height: 0.026246719160104987
#
# 📦 Energy Analysis
# • Actual Lighting Load: 0.0
# • Actual Lighting Load per area: 0.0
# • Actual Power Load: 0.0
# • Actual Power Load per area: 0.0
# • Area per Person: 0.0
# • Base Lighting Load on: By Space Type
# • Base Power Load on: By Space Type
# • Heat Load Values: By Space Type
# • Lighting Load Units: Power Density
# • Number of People: 0.0
# • Power Load Units: Power Density
# • Specified Lighting Load: 0.0
# • Specified Lighting Load per area: 0.0
# • Specified Power Load: 0.0
# • Specified Power Load per area: 0.0
# • Total Heat Gain per person: 0.0
#
# 📦 Identity Data
# • Name: Cafe
# • Number: 1
# • Workset: Shared Levels and Grids
#
# 📦 Phasing
# • Phase: Новая конструкция

# %%
elements = inspector.get_elements_by_category("architecture", "walls")
for i in elements:
    print(i.get_info())
    for k, v in i.get_info().items():
        print(f"{k}: {v}")
    print("\n")
# Out:
# {'id': 4425, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzLf', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:475646', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4414=IfcLocalPlacement(#38,#4413), 'Representation': #4424=IfcProductDefinitionShape($,$,(#4417,#4423)), 'Tag': '475646', 'PredefinedType': 'NOTDEFINED'}
# id: 4425
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzLf
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:475646
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4414=IfcLocalPlacement(#38,#4413)
# Representation: #4424=IfcProductDefinitionShape($,$,(#4417,#4423))
# Tag: 475646
# PredefinedType: NOTDEFINED
#
#
# {'id': 4629, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzLe', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:475647', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4618=IfcLocalPlacement(#38,#4617), 'Representation': #4628=IfcProductDefinitionShape($,$,(#4621,#4627)), 'Tag': '475647', 'PredefinedType': 'NOTDEFINED'}
# id: 4629
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzLe
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:475647
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4618=IfcLocalPlacement(#38,#4617)
# Representation: #4628=IfcProductDefinitionShape($,$,(#4621,#4627))
# Tag: 475647
# PredefinedType: NOTDEFINED
#
#
# {'id': 4831, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUz', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:475946', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4820=IfcLocalPlacement(#46,#4819), 'Representation': #4830=IfcProductDefinitionShape($,$,(#4823,#4829)), 'Tag': '475946', 'PredefinedType': 'NOTDEFINED'}
# id: 4831
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUz
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:475946
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4820=IfcLocalPlacement(#46,#4819)
# Representation: #4830=IfcProductDefinitionShape($,$,(#4823,#4829))
# Tag: 475946
# PredefinedType: NOTDEFINED
#
#
# {'id': 4869, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUy', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:475947', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4858=IfcLocalPlacement(#46,#4857), 'Representation': #4868=IfcProductDefinitionShape($,$,(#4861,#4867)), 'Tag': '475947', 'PredefinedType': 'NOTDEFINED'}
# id: 4869
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUy
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:475947
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4858=IfcLocalPlacement(#46,#4857)
# Representation: #4868=IfcProductDefinitionShape($,$,(#4861,#4867))
# Tag: 475947
# PredefinedType: NOTDEFINED
#
#
# {'id': 4905, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUx', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:475948', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4894=IfcLocalPlacement(#46,#4893), 'Representation': #4904=IfcProductDefinitionShape($,$,(#4897,#4903)), 'Tag': '475948', 'PredefinedType': 'NOTDEFINED'}
# id: 4905
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUx
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:475948
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4894=IfcLocalPlacement(#46,#4893)
# Representation: #4904=IfcProductDefinitionShape($,$,(#4897,#4903))
# Tag: 475948
# PredefinedType: NOTDEFINED
#
#
# {'id': 4941, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUw', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:475949', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4930=IfcLocalPlacement(#46,#4929), 'Representation': #4940=IfcProductDefinitionShape($,$,(#4933,#4939)), 'Tag': '475949', 'PredefinedType': 'NOTDEFINED'}
# id: 4941
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUw
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:475949
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4930=IfcLocalPlacement(#46,#4929)
# Representation: #4940=IfcProductDefinitionShape($,$,(#4933,#4939))
# Tag: 475949
# PredefinedType: NOTDEFINED
#
#
# {'id': 5105, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEI', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:476933', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5094=IfcLocalPlacement(#54,#5093), 'Representation': #5104=IfcProductDefinitionShape($,$,(#5097,#5103)), 'Tag': '476933', 'PredefinedType': 'NOTDEFINED'}
# id: 5105
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEI
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:476933
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5094=IfcLocalPlacement(#54,#5093)
# Representation: #5104=IfcProductDefinitionShape($,$,(#5097,#5103))
# Tag: 476933
# PredefinedType: NOTDEFINED
#
#
# {'id': 5142, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEH', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:476934', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5131=IfcLocalPlacement(#54,#5130), 'Representation': #5141=IfcProductDefinitionShape($,$,(#5134,#5140)), 'Tag': '476934', 'PredefinedType': 'NOTDEFINED'}
# id: 5142
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEH
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:476934
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5131=IfcLocalPlacement(#54,#5130)
# Representation: #5141=IfcProductDefinitionShape($,$,(#5134,#5140))
# Tag: 476934
# PredefinedType: NOTDEFINED
#
#
# {'id': 5178, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEG', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:476935', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5167=IfcLocalPlacement(#54,#5166), 'Representation': #5177=IfcProductDefinitionShape($,$,(#5170,#5176)), 'Tag': '476935', 'PredefinedType': 'NOTDEFINED'}
# id: 5178
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEG
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:476935
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5167=IfcLocalPlacement(#54,#5166)
# Representation: #5177=IfcProductDefinitionShape($,$,(#5170,#5176))
# Tag: 476935
# PredefinedType: NOTDEFINED
#
#
# {'id': 5214, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEV', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:476936', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5203=IfcLocalPlacement(#54,#5202), 'Representation': #5213=IfcProductDefinitionShape($,$,(#5206,#5212)), 'Tag': '476936', 'PredefinedType': 'NOTDEFINED'}
# id: 5214
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEV
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:476936
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5203=IfcLocalPlacement(#54,#5202)
# Representation: #5213=IfcProductDefinitionShape($,$,(#5206,#5212))
# Tag: 476936
# PredefinedType: NOTDEFINED
#
#
# {'id': 5250, 'type': 'IfcWall', 'GlobalId': '2QL1yxPdz0mf0HRGtpkIjd', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:477836', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5239=IfcLocalPlacement(#35,#5238), 'Representation': #5249=IfcProductDefinitionShape($,$,(#5242,#5248)), 'Tag': '477836', 'PredefinedType': 'NOTDEFINED'}
# id: 5250
# type: IfcWall
# GlobalId: 2QL1yxPdz0mf0HRGtpkIjd
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:477836
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5239=IfcLocalPlacement(#35,#5238)
# Representation: #5249=IfcProductDefinitionShape($,$,(#5242,#5248))
# Tag: 477836
# PredefinedType: NOTDEFINED
#
#
# {'id': 5343, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTD5U', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:478828', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5332=IfcLocalPlacement(#35,#5331), 'Representation': #5342=IfcProductDefinitionShape($,$,(#5335,#5341)), 'Tag': '478828', 'PredefinedType': 'NOTDEFINED'}
# id: 5343
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTD5U
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:478828
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5332=IfcLocalPlacement(#35,#5331)
# Representation: #5342=IfcProductDefinitionShape($,$,(#5335,#5341))
# Tag: 478828
# PredefinedType: NOTDEFINED
#
#
# {'id': 5380, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTCpQ', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:480232', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #5369=IfcLocalPlacement(#38,#5368), 'Representation': #5379=IfcProductDefinitionShape($,$,(#5372,#5378)), 'Tag': '480232', 'PredefinedType': 'NOTDEFINED'}
# id: 5380
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTCpQ
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:480232
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #5369=IfcLocalPlacement(#38,#5368)
# Representation: #5379=IfcProductDefinitionShape($,$,(#5372,#5378))
# Tag: 480232
# PredefinedType: NOTDEFINED
#
#
# {'id': 7052, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTCDe', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:482394', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #7041=IfcLocalPlacement(#35,#7040), 'Representation': #7051=IfcProductDefinitionShape($,$,(#7044,#7050)), 'Tag': '482394', 'PredefinedType': 'NOTDEFINED'}
# id: 7052
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTCDe
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:482394
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #7041=IfcLocalPlacement(#35,#7040)
# Representation: #7051=IfcProductDefinitionShape($,$,(#7044,#7050))
# Tag: 482394
# PredefinedType: NOTDEFINED
#
#
# {'id': 7089, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTC6f', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:482971', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #7078=IfcLocalPlacement(#35,#7077), 'Representation': #7088=IfcProductDefinitionShape($,$,(#7081,#7087)), 'Tag': '482971', 'PredefinedType': 'NOTDEFINED'}
# id: 7089
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTC6f
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:482971
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #7078=IfcLocalPlacement(#35,#7077)
# Representation: #7088=IfcProductDefinitionShape($,$,(#7081,#7087))
# Tag: 482971
# PredefinedType: NOTDEFINED
#
#
# {'id': 13647, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7K5p', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:487136', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #13635=IfcLocalPlacement(#38,#13634), 'Representation': #13646=IfcProductDefinitionShape($,$,(#13638,#13645)), 'Tag': '487136', 'PredefinedType': 'NOTDEFINED'}
# id: 13647
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7K5p
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:487136
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #13635=IfcLocalPlacement(#38,#13634)
# Representation: #13646=IfcProductDefinitionShape($,$,(#13638,#13645))
# Tag: 487136
# PredefinedType: NOTDEFINED
#
#
# {'id': 13701, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7K35', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:487254', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #13689=IfcLocalPlacement(#38,#13688), 'Representation': #13700=IfcProductDefinitionShape($,$,(#13692,#13699)), 'Tag': '487254', 'PredefinedType': 'NOTDEFINED'}
# id: 13701
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7K35
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:487254
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #13689=IfcLocalPlacement(#38,#13688)
# Representation: #13700=IfcProductDefinitionShape($,$,(#13692,#13699))
# Tag: 487254
# PredefinedType: NOTDEFINED
#
#
# {'id': 13738, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7K0C', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:487327', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #13726=IfcLocalPlacement(#38,#13725), 'Representation': #13737=IfcProductDefinitionShape($,$,(#13729,#13736)), 'Tag': '487327', 'PredefinedType': 'NOTDEFINED'}
# id: 13738
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7K0C
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:487327
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #13726=IfcLocalPlacement(#38,#13725)
# Representation: #13737=IfcProductDefinitionShape($,$,(#13729,#13736))
# Tag: 487327
# PredefinedType: NOTDEFINED
#
#
# {'id': 13774, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7L$j', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:487550', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #13763=IfcLocalPlacement(#38,#13762), 'Representation': #13773=IfcProductDefinitionShape($,$,(#13766,#13772)), 'Tag': '487550', 'PredefinedType': 'NOTDEFINED'}
# id: 13774
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7L$j
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:487550
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #13763=IfcLocalPlacement(#38,#13762)
# Representation: #13773=IfcProductDefinitionShape($,$,(#13766,#13772))
# Tag: 487550
# PredefinedType: NOTDEFINED
#
#
# {'id': 14716, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZg18', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:488700', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #14704=IfcLocalPlacement(#38,#14703), 'Representation': #14715=IfcProductDefinitionShape($,$,(#14707,#14714)), 'Tag': '488700', 'PredefinedType': 'NOTDEFINED'}
# id: 14716
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZg18
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:488700
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #14704=IfcLocalPlacement(#38,#14703)
# Representation: #14715=IfcProductDefinitionShape($,$,(#14707,#14714))
# Tag: 488700
# PredefinedType: NOTDEFINED
#
#
# {'id': 14753, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgAn', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:488965', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #14741=IfcLocalPlacement(#38,#14740), 'Representation': #14752=IfcProductDefinitionShape($,$,(#14744,#14751)), 'Tag': '488965', 'PredefinedType': 'NOTDEFINED'}
# id: 14753
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgAn
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:488965
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #14741=IfcLocalPlacement(#38,#14740)
# Representation: #14752=IfcProductDefinitionShape($,$,(#14744,#14751))
# Tag: 488965
# PredefinedType: NOTDEFINED
#
#
# {'id': 14994, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgmF', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489659', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #14982=IfcLocalPlacement(#46,#14981), 'Representation': #14993=IfcProductDefinitionShape($,$,(#14985,#14992)), 'Tag': '489659', 'PredefinedType': 'NOTDEFINED'}
# id: 14994
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgmF
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489659
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #14982=IfcLocalPlacement(#46,#14981)
# Representation: #14993=IfcProductDefinitionShape($,$,(#14985,#14992))
# Tag: 489659
# PredefinedType: NOTDEFINED
#
#
# {'id': 15031, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgm8', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489660', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #15019=IfcLocalPlacement(#46,#15018), 'Representation': #15030=IfcProductDefinitionShape($,$,(#15022,#15029)), 'Tag': '489660', 'PredefinedType': 'NOTDEFINED'}
# id: 15031
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgm8
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489660
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #15019=IfcLocalPlacement(#46,#15018)
# Representation: #15030=IfcProductDefinitionShape($,$,(#15022,#15029))
# Tag: 489660
# PredefinedType: NOTDEFINED
#
#
# {'id': 15068, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgm9', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489661', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #15056=IfcLocalPlacement(#46,#15055), 'Representation': #15067=IfcProductDefinitionShape($,$,(#15059,#15066)), 'Tag': '489661', 'PredefinedType': 'NOTDEFINED'}
# id: 15068
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgm9
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489661
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #15056=IfcLocalPlacement(#46,#15055)
# Representation: #15067=IfcProductDefinitionShape($,$,(#15059,#15066))
# Tag: 489661
# PredefinedType: NOTDEFINED
#
#
# {'id': 15265, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgnt', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489667', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #15253=IfcLocalPlacement(#54,#15252), 'Representation': #15264=IfcProductDefinitionShape($,$,(#15256,#15263)), 'Tag': '489667', 'PredefinedType': 'NOTDEFINED'}
# id: 15265
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgnt
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489667
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #15253=IfcLocalPlacement(#54,#15252)
# Representation: #15264=IfcProductDefinitionShape($,$,(#15256,#15263))
# Tag: 489667
# PredefinedType: NOTDEFINED
#
#
# {'id': 15302, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgnm', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489668', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #15290=IfcLocalPlacement(#54,#15289), 'Representation': #15301=IfcProductDefinitionShape($,$,(#15293,#15300)), 'Tag': '489668', 'PredefinedType': 'NOTDEFINED'}
# id: 15302
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgnm
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489668
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #15290=IfcLocalPlacement(#54,#15289)
# Representation: #15301=IfcProductDefinitionShape($,$,(#15293,#15300))
# Tag: 489668
# PredefinedType: NOTDEFINED
#
#
# {'id': 15339, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgnn', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489669', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #15327=IfcLocalPlacement(#54,#15326), 'Representation': #15338=IfcProductDefinitionShape($,$,(#15330,#15337)), 'Tag': '489669', 'PredefinedType': 'NOTDEFINED'}
# id: 15339
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgnn
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489669
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #15327=IfcLocalPlacement(#54,#15326)
# Representation: #15338=IfcProductDefinitionShape($,$,(#15330,#15337))
# Tag: 489669
# PredefinedType: NOTDEFINED
#
#
# {'id': 16251, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgvD', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490233', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #16239=IfcLocalPlacement(#38,#16238), 'Representation': #16250=IfcProductDefinitionShape($,$,(#16242,#16249)), 'Tag': '490233', 'PredefinedType': 'NOTDEFINED'}
# id: 16251
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgvD
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490233
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #16239=IfcLocalPlacement(#38,#16238)
# Representation: #16250=IfcProductDefinitionShape($,$,(#16242,#16249))
# Tag: 490233
# PredefinedType: NOTDEFINED
#
#
# {'id': 16288, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgc1', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490805', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #16276=IfcLocalPlacement(#46,#16275), 'Representation': #16287=IfcProductDefinitionShape($,$,(#16279,#16286)), 'Tag': '490805', 'PredefinedType': 'NOTDEFINED'}
# id: 16288
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgc1
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490805
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #16276=IfcLocalPlacement(#46,#16275)
# Representation: #16287=IfcProductDefinitionShape($,$,(#16279,#16286))
# Tag: 490805
# PredefinedType: NOTDEFINED
#
#
# {'id': 16326, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgc2', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490806', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #16314=IfcLocalPlacement(#46,#16313), 'Representation': #16325=IfcProductDefinitionShape($,$,(#16317,#16324)), 'Tag': '490806', 'PredefinedType': 'NOTDEFINED'}
# id: 16326
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgc2
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490806
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #16314=IfcLocalPlacement(#46,#16313)
# Representation: #16325=IfcProductDefinitionShape($,$,(#16317,#16324))
# Tag: 490806
# PredefinedType: NOTDEFINED
#
#
# {'id': 16364, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgcD', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490809', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #16352=IfcLocalPlacement(#54,#16351), 'Representation': #16363=IfcProductDefinitionShape($,$,(#16355,#16362)), 'Tag': '490809', 'PredefinedType': 'NOTDEFINED'}
# id: 16364
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgcD
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490809
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #16352=IfcLocalPlacement(#54,#16351)
# Representation: #16363=IfcProductDefinitionShape($,$,(#16355,#16362))
# Tag: 490809
# PredefinedType: NOTDEFINED
#
#
# {'id': 22834, 'type': 'IfcWall', 'GlobalId': '3y00uNPof8qhaDFLl2ZQCk', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160:492580', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160', 'ObjectPlacement': #22819=IfcLocalPlacement(#38,#22818), 'Representation': #22833=IfcProductDefinitionShape($,$,(#22822,#22832)), 'Tag': '492580', 'PredefinedType': 'NOTDEFINED'}
# id: 22834
# type: IfcWall
# GlobalId: 3y00uNPof8qhaDFLl2ZQCk
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160:492580
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160
# ObjectPlacement: #22819=IfcLocalPlacement(#38,#22818)
# Representation: #22833=IfcProductDefinitionShape($,$,(#22822,#22832))
# Tag: 492580
# PredefinedType: NOTDEFINED
#
#
# {'id': 23666, 'type': 'IfcWall', 'GlobalId': '1qn_HvrIf1nxexJJxrV$Lm', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526), 'Name': 'Basic Wall:Базовая - 200мм:494171', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #23655=IfcLocalPlacement(#38,#23654), 'Representation': #23665=IfcProductDefinitionShape($,$,(#23658,#23664)), 'Tag': '494171', 'PredefinedType': 'NOTDEFINED'}
# id: 23666
# type: IfcWall
# GlobalId: 1qn_HvrIf1nxexJJxrV$Lm
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743193526)
# Name: Basic Wall:Базовая - 200мм:494171
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #23655=IfcLocalPlacement(#38,#23654)
# Representation: #23665=IfcProductDefinitionShape($,$,(#23658,#23664))
# Tag: 494171
# PredefinedType: NOTDEFINED

# %%
el = inspector.get_element("architecture", "doors", 0)

print("📍 Позиция (placement):", inspector.get_coordinates(el))
print("📍 Геометрия (центр):", inspector.get_coordinates_geom(el))
print("📦 Bounding box:", inspector.get_bounding_box(el))
print("🔎 Площадь:", inspector.get_field_value(el, "GrossArea"))
inspector.get_hierarchy(el)
# Out:
# 📍 Позиция (placement): (9900.0, 600.0, 0.0)
# 📍 Геометрия (центр): (9.15, -0.0791489731114339, 0.9896276595746151)
# 📦 Bounding box: {'min': (8.4, -0.16200000000000003, 0.0), 'max': (9.9, 0.0020000000000000018, 2.1), 'size': (1.5, 0.16400000000000003, 2.1)}
# 🔎 Площадь: None
#
# 📂 Иерархия для элемента: AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974
# • IfcDoor — AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974 [GUID: 34MLEKJFT2ifDJcPAg7Kdz]
# • IfcBuildingStorey — Этаж 01 [GUID: 3JdBMZYHv1MPtLo1gvmLGu]
# • IfcBuilding — Наименование здания [GUID: 05P6TmP8X2jg_clMvevcmI]
# • IfcSite — Default [GUID: 05P6TmP8X2jg_clMvevcmH]
# • IfcProject — Номер проекта [GUID: 05P6TmP8X2jg_clMvevcmJ]

# %%
analyzer.list_available()
# Показать все доступные типы элементов
# Out:
# 📚 Доступные категории и типы элементов:
#
# ARCHITECTURE:
#   - spaces
#   - walls
#   - doors
#   - windows
#   - slabs
#   - stairs
#   - railings
#   - coverings
#   - facades
#
# STRUCTURE:
#   - columns
#   - beams
#   - slabs
#   - footings
#
# METAL:
#   - members
#   - plates
#   - columns
#   - beams
