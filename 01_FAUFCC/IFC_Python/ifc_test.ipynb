# %%
import ifcopenshell

# %%
from ifc_loader import IFCLoader
from ifc_element_inspector import IFCElementInspector
from ifc_analyzer import IFCAnalyzer
from ifc_dataset_builder import IFCDatasetBuilder

# %%
class IFCLoader:
    def __init__(self, file_path: str):
        self.file_path = file_path
        self.model = None

    def load(self):
        self.model = ifcopenshell.open(self.file_path)
        return self.model

    def reload(self):
        return self.load()

# %%
loader = IFCLoader("data/2025_01_AR_mid.ifc")
model = loader.load()

builder = IFCDatasetBuilder(model)
dataset = builder.build()

analyzer = IFCAnalyzer(dataset)
inspector = IFCElementInspector(dataset)

# %%
# Показать сводку
analyzer.print_summary()
# Out:
# 📊 Общая сводка по всем категориям:
# Architecture: 70 элементов
# Structure: 6 элементов
# Metal: 244 элементов

# %%
analyzer.print_summary("architecture")
# Out:
# 📂 Сводка по категории 'ARCHITECTURE':
# • Spaces: 4 шт.
# • Walls: 33 шт.
# • Doors: 16 шт.
# • Windows: 0 шт.
# • Slabs: 6 шт.
# • Stairs: 2 шт.
# • Railings: 2 шт.
# • Coverings: 0 шт.
# • Facades: 7 шт.

# %%
# Показать все двери архитектуры
analyzer.print_elements("architecture", "doors")
# Out:
# 🔍 Элементы 'doors' из категории 'architecture':
# - AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974 [GUID: 34MLEKJFT2ifDJcPAg7Kdz]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:486634 [GUID: 34MLEKJFT2ifDJcPAg7KDv]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489130 [GUID: 3at$GBZPL3SxpFATHfZg8U]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489375 [GUID: 3at$GBZPL3SxpFATHfZgCh]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489453 [GUID: 3at$GBZPL3SxpFATHfZgDP]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489662 [GUID: 3at$GBZPL3SxpFATHfZgmA]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489663 [GUID: 3at$GBZPL3SxpFATHfZgmB]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489664 [GUID: 3at$GBZPL3SxpFATHfZgnq]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489670 [GUID: 3at$GBZPL3SxpFATHfZgno]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489671 [GUID: 3at$GBZPL3SxpFATHfZgnp]
# - ADSK_Дверь_Проем:ADSK_Дверь_Проем:489672 [GUID: 3at$GBZPL3SxpFATHfZgny]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:490057 [GUID: 3at$GBZPL3SxpFATHfZgxz]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:491206 [GUID: 3at$GBZPL3SxpFATHfZgfo]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:491210 [GUID: 3at$GBZPL3SxpFATHfZgf_]
# - AC_Дверь_Двупольная_Стальная:1360х2080h Н О Л:492129 [GUID: 3y00uNPof8qhaDFLl2ZQLh]
# - AC_Дверь_Однопольная_Стальная:1060х2080h В О Л:492952 [GUID: 3y00uNPof8qhaDFLl2ZQAI]

# %%
# Печатаем все параметры всех помещений
analyzer.print_element_properties("architecture", "doors")
# Out:
# 🔍 Свойства элемента типа 'doors' (первый из 16):
#
# 📄 Основные поля IFC:
# • Name: AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974
# • ObjectType: AC_Дверь_Двупольная_Стальная:1460х2080h Н
# • GlobalId: 34MLEKJFT2ifDJcPAg7Kdz
# • PredefinedType: DOOR
#
# 🧩 Свойства из PropertySet-ов:
#
# 📦 Pset_DoorCommon
# • IsExternal: True
# • Reference: 1460х2080h Н
#
# 📦 Pset_EnvironmentalImpactIndicators
# • Reference: 1460х2080h Н

# %%
elements = inspector.get_elements_by_category("architecture", "walls")
for i in elements:
    print(i.get_info())
    for k, v in i.get_info().items():
        print(f"{k}: {v}")
    print("\n")
# Out:
# {'id': 2667, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzLf', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:475646', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #2656=IfcLocalPlacement(#38,#2655), 'Representation': #2666=IfcProductDefinitionShape($,$,(#2659,#2665)), 'Tag': '475646', 'PredefinedType': 'NOTDEFINED'}
# id: 2667
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzLf
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:475646
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #2656=IfcLocalPlacement(#38,#2655)
# Representation: #2666=IfcProductDefinitionShape($,$,(#2659,#2665))
# Tag: 475646
# PredefinedType: NOTDEFINED
#
#
# {'id': 2717, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzLe', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:475647', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #2706=IfcLocalPlacement(#38,#2705), 'Representation': #2716=IfcProductDefinitionShape($,$,(#2709,#2715)), 'Tag': '475647', 'PredefinedType': 'NOTDEFINED'}
# id: 2717
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzLe
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:475647
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #2706=IfcLocalPlacement(#38,#2705)
# Representation: #2716=IfcProductDefinitionShape($,$,(#2709,#2715))
# Tag: 475647
# PredefinedType: NOTDEFINED
#
#
# {'id': 2860, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUz', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:475946', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #2849=IfcLocalPlacement(#46,#2848), 'Representation': #2859=IfcProductDefinitionShape($,$,(#2852,#2858)), 'Tag': '475946', 'PredefinedType': 'NOTDEFINED'}
# id: 2860
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUz
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:475946
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #2849=IfcLocalPlacement(#46,#2848)
# Representation: #2859=IfcProductDefinitionShape($,$,(#2852,#2858))
# Tag: 475946
# PredefinedType: NOTDEFINED
#
#
# {'id': 2881, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUy', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:475947', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #2870=IfcLocalPlacement(#46,#2869), 'Representation': #2880=IfcProductDefinitionShape($,$,(#2873,#2879)), 'Tag': '475947', 'PredefinedType': 'NOTDEFINED'}
# id: 2881
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUy
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:475947
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #2870=IfcLocalPlacement(#46,#2869)
# Representation: #2880=IfcProductDefinitionShape($,$,(#2873,#2879))
# Tag: 475947
# PredefinedType: NOTDEFINED
#
#
# {'id': 2902, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUx', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:475948', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #2891=IfcLocalPlacement(#46,#2890), 'Representation': #2901=IfcProductDefinitionShape($,$,(#2894,#2900)), 'Tag': '475948', 'PredefinedType': 'NOTDEFINED'}
# id: 2902
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUx
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:475948
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #2891=IfcLocalPlacement(#46,#2890)
# Representation: #2901=IfcProductDefinitionShape($,$,(#2894,#2900))
# Tag: 475948
# PredefinedType: NOTDEFINED
#
#
# {'id': 2923, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzUw', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:475949', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #2912=IfcLocalPlacement(#46,#2911), 'Representation': #2922=IfcProductDefinitionShape($,$,(#2915,#2921)), 'Tag': '475949', 'PredefinedType': 'NOTDEFINED'}
# id: 2923
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzUw
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:475949
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #2912=IfcLocalPlacement(#46,#2911)
# Representation: #2922=IfcProductDefinitionShape($,$,(#2915,#2921))
# Tag: 475949
# PredefinedType: NOTDEFINED
#
#
# {'id': 3030, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEI', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:476933', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3019=IfcLocalPlacement(#54,#3018), 'Representation': #3029=IfcProductDefinitionShape($,$,(#3022,#3028)), 'Tag': '476933', 'PredefinedType': 'NOTDEFINED'}
# id: 3030
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEI
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:476933
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3019=IfcLocalPlacement(#54,#3018)
# Representation: #3029=IfcProductDefinitionShape($,$,(#3022,#3028))
# Tag: 476933
# PredefinedType: NOTDEFINED
#
#
# {'id': 3051, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEH', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:476934', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3040=IfcLocalPlacement(#54,#3039), 'Representation': #3050=IfcProductDefinitionShape($,$,(#3043,#3049)), 'Tag': '476934', 'PredefinedType': 'NOTDEFINED'}
# id: 3051
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEH
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:476934
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3040=IfcLocalPlacement(#54,#3039)
# Representation: #3050=IfcProductDefinitionShape($,$,(#3043,#3049))
# Tag: 476934
# PredefinedType: NOTDEFINED
#
#
# {'id': 3072, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEG', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:476935', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3061=IfcLocalPlacement(#54,#3060), 'Representation': #3071=IfcProductDefinitionShape($,$,(#3064,#3070)), 'Tag': '476935', 'PredefinedType': 'NOTDEFINED'}
# id: 3072
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEG
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:476935
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3061=IfcLocalPlacement(#54,#3060)
# Representation: #3071=IfcProductDefinitionShape($,$,(#3064,#3070))
# Tag: 476935
# PredefinedType: NOTDEFINED
#
#
# {'id': 3093, 'type': 'IfcWall', 'GlobalId': '1f66i6aMvEdPnb_ydTlzEV', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:476936', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3082=IfcLocalPlacement(#54,#3081), 'Representation': #3092=IfcProductDefinitionShape($,$,(#3085,#3091)), 'Tag': '476936', 'PredefinedType': 'NOTDEFINED'}
# id: 3093
# type: IfcWall
# GlobalId: 1f66i6aMvEdPnb_ydTlzEV
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:476936
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3082=IfcLocalPlacement(#54,#3081)
# Representation: #3092=IfcProductDefinitionShape($,$,(#3085,#3091))
# Tag: 476936
# PredefinedType: NOTDEFINED
#
#
# {'id': 3114, 'type': 'IfcWall', 'GlobalId': '2QL1yxPdz0mf0HRGtpkIjd', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:477836', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3103=IfcLocalPlacement(#35,#3102), 'Representation': #3113=IfcProductDefinitionShape($,$,(#3106,#3112)), 'Tag': '477836', 'PredefinedType': 'NOTDEFINED'}
# id: 3114
# type: IfcWall
# GlobalId: 2QL1yxPdz0mf0HRGtpkIjd
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:477836
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3103=IfcLocalPlacement(#35,#3102)
# Representation: #3113=IfcProductDefinitionShape($,$,(#3106,#3112))
# Tag: 477836
# PredefinedType: NOTDEFINED
#
#
# {'id': 3160, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTD5U', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:478828', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3149=IfcLocalPlacement(#35,#3148), 'Representation': #3159=IfcProductDefinitionShape($,$,(#3152,#3158)), 'Tag': '478828', 'PredefinedType': 'NOTDEFINED'}
# id: 3160
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTD5U
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:478828
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3149=IfcLocalPlacement(#35,#3148)
# Representation: #3159=IfcProductDefinitionShape($,$,(#3152,#3158))
# Tag: 478828
# PredefinedType: NOTDEFINED
#
#
# {'id': 3181, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTCpQ', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:480232', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #3170=IfcLocalPlacement(#38,#3169), 'Representation': #3180=IfcProductDefinitionShape($,$,(#3173,#3179)), 'Tag': '480232', 'PredefinedType': 'NOTDEFINED'}
# id: 3181
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTCpQ
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:480232
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #3170=IfcLocalPlacement(#38,#3169)
# Representation: #3180=IfcProductDefinitionShape($,$,(#3173,#3179))
# Tag: 480232
# PredefinedType: NOTDEFINED
#
#
# {'id': 4172, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTCDe', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:482394', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4161=IfcLocalPlacement(#35,#4160), 'Representation': #4171=IfcProductDefinitionShape($,$,(#4164,#4170)), 'Tag': '482394', 'PredefinedType': 'NOTDEFINED'}
# id: 4172
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTCDe
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:482394
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4161=IfcLocalPlacement(#35,#4160)
# Representation: #4171=IfcProductDefinitionShape($,$,(#4164,#4170))
# Tag: 482394
# PredefinedType: NOTDEFINED
#
#
# {'id': 4193, 'type': 'IfcWall', 'GlobalId': '0NIB57Llf6eh4kZI$MTC6f', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:482971', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #4182=IfcLocalPlacement(#35,#4181), 'Representation': #4192=IfcProductDefinitionShape($,$,(#4185,#4191)), 'Tag': '482971', 'PredefinedType': 'NOTDEFINED'}
# id: 4193
# type: IfcWall
# GlobalId: 0NIB57Llf6eh4kZI$MTC6f
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:482971
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #4182=IfcLocalPlacement(#35,#4181)
# Representation: #4192=IfcProductDefinitionShape($,$,(#4185,#4191))
# Tag: 482971
# PredefinedType: NOTDEFINED
#
#
# {'id': 10437, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7K5p', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:487136', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #10425=IfcLocalPlacement(#38,#10424), 'Representation': #10436=IfcProductDefinitionShape($,$,(#10428,#10435)), 'Tag': '487136', 'PredefinedType': 'NOTDEFINED'}
# id: 10437
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7K5p
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:487136
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #10425=IfcLocalPlacement(#38,#10424)
# Representation: #10436=IfcProductDefinitionShape($,$,(#10428,#10435))
# Tag: 487136
# PredefinedType: NOTDEFINED
#
#
# {'id': 10464, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7K35', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:487254', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #10452=IfcLocalPlacement(#38,#10451), 'Representation': #10463=IfcProductDefinitionShape($,$,(#10455,#10462)), 'Tag': '487254', 'PredefinedType': 'NOTDEFINED'}
# id: 10464
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7K35
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:487254
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #10452=IfcLocalPlacement(#38,#10451)
# Representation: #10463=IfcProductDefinitionShape($,$,(#10455,#10462))
# Tag: 487254
# PredefinedType: NOTDEFINED
#
#
# {'id': 10486, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7K0C', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:487327', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #10474=IfcLocalPlacement(#38,#10473), 'Representation': #10485=IfcProductDefinitionShape($,$,(#10477,#10484)), 'Tag': '487327', 'PredefinedType': 'NOTDEFINED'}
# id: 10486
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7K0C
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:487327
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #10474=IfcLocalPlacement(#38,#10473)
# Representation: #10485=IfcProductDefinitionShape($,$,(#10477,#10484))
# Tag: 487327
# PredefinedType: NOTDEFINED
#
#
# {'id': 10507, 'type': 'IfcWall', 'GlobalId': '34MLEKJFT2ifDJcPAg7L$j', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:487550', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #10496=IfcLocalPlacement(#38,#10495), 'Representation': #10506=IfcProductDefinitionShape($,$,(#10499,#10505)), 'Tag': '487550', 'PredefinedType': 'NOTDEFINED'}
# id: 10507
# type: IfcWall
# GlobalId: 34MLEKJFT2ifDJcPAg7L$j
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:487550
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #10496=IfcLocalPlacement(#38,#10495)
# Representation: #10506=IfcProductDefinitionShape($,$,(#10499,#10505))
# Tag: 487550
# PredefinedType: NOTDEFINED
#
#
# {'id': 11083, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZg18', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:488700', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11071=IfcLocalPlacement(#38,#11070), 'Representation': #11082=IfcProductDefinitionShape($,$,(#11074,#11081)), 'Tag': '488700', 'PredefinedType': 'NOTDEFINED'}
# id: 11083
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZg18
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:488700
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11071=IfcLocalPlacement(#38,#11070)
# Representation: #11082=IfcProductDefinitionShape($,$,(#11074,#11081))
# Tag: 488700
# PredefinedType: NOTDEFINED
#
#
# {'id': 11105, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgAn', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:488965', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11093=IfcLocalPlacement(#38,#11092), 'Representation': #11104=IfcProductDefinitionShape($,$,(#11096,#11103)), 'Tag': '488965', 'PredefinedType': 'NOTDEFINED'}
# id: 11105
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgAn
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:488965
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11093=IfcLocalPlacement(#38,#11092)
# Representation: #11104=IfcProductDefinitionShape($,$,(#11096,#11103))
# Tag: 488965
# PredefinedType: NOTDEFINED
#
#
# {'id': 11157, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgmF', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489659', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11145=IfcLocalPlacement(#46,#11144), 'Representation': #11156=IfcProductDefinitionShape($,$,(#11148,#11155)), 'Tag': '489659', 'PredefinedType': 'NOTDEFINED'}
# id: 11157
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgmF
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489659
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11145=IfcLocalPlacement(#46,#11144)
# Representation: #11156=IfcProductDefinitionShape($,$,(#11148,#11155))
# Tag: 489659
# PredefinedType: NOTDEFINED
#
#
# {'id': 11179, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgm8', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489660', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11167=IfcLocalPlacement(#46,#11166), 'Representation': #11178=IfcProductDefinitionShape($,$,(#11170,#11177)), 'Tag': '489660', 'PredefinedType': 'NOTDEFINED'}
# id: 11179
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgm8
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489660
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11167=IfcLocalPlacement(#46,#11166)
# Representation: #11178=IfcProductDefinitionShape($,$,(#11170,#11177))
# Tag: 489660
# PredefinedType: NOTDEFINED
#
#
# {'id': 11201, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgm9', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489661', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11189=IfcLocalPlacement(#46,#11188), 'Representation': #11200=IfcProductDefinitionShape($,$,(#11192,#11199)), 'Tag': '489661', 'PredefinedType': 'NOTDEFINED'}
# id: 11201
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgm9
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489661
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11189=IfcLocalPlacement(#46,#11188)
# Representation: #11200=IfcProductDefinitionShape($,$,(#11192,#11199))
# Tag: 489661
# PredefinedType: NOTDEFINED
#
#
# {'id': 11247, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgnt', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489667', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11235=IfcLocalPlacement(#54,#11234), 'Representation': #11246=IfcProductDefinitionShape($,$,(#11238,#11245)), 'Tag': '489667', 'PredefinedType': 'NOTDEFINED'}
# id: 11247
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgnt
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489667
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11235=IfcLocalPlacement(#54,#11234)
# Representation: #11246=IfcProductDefinitionShape($,$,(#11238,#11245))
# Tag: 489667
# PredefinedType: NOTDEFINED
#
#
# {'id': 11269, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgnm', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489668', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11257=IfcLocalPlacement(#54,#11256), 'Representation': #11268=IfcProductDefinitionShape($,$,(#11260,#11267)), 'Tag': '489668', 'PredefinedType': 'NOTDEFINED'}
# id: 11269
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgnm
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489668
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11257=IfcLocalPlacement(#54,#11256)
# Representation: #11268=IfcProductDefinitionShape($,$,(#11260,#11267))
# Tag: 489668
# PredefinedType: NOTDEFINED
#
#
# {'id': 11291, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgnn', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:489669', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11279=IfcLocalPlacement(#54,#11278), 'Representation': #11290=IfcProductDefinitionShape($,$,(#11282,#11289)), 'Tag': '489669', 'PredefinedType': 'NOTDEFINED'}
# id: 11291
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgnn
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:489669
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11279=IfcLocalPlacement(#54,#11278)
# Representation: #11290=IfcProductDefinitionShape($,$,(#11282,#11289))
# Tag: 489669
# PredefinedType: NOTDEFINED
#
#
# {'id': 11944, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgvD', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490233', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11932=IfcLocalPlacement(#38,#11931), 'Representation': #11943=IfcProductDefinitionShape($,$,(#11935,#11942)), 'Tag': '490233', 'PredefinedType': 'NOTDEFINED'}
# id: 11944
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgvD
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490233
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11932=IfcLocalPlacement(#38,#11931)
# Representation: #11943=IfcProductDefinitionShape($,$,(#11935,#11942))
# Tag: 490233
# PredefinedType: NOTDEFINED
#
#
# {'id': 11966, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgc1', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490805', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11954=IfcLocalPlacement(#46,#11953), 'Representation': #11965=IfcProductDefinitionShape($,$,(#11957,#11964)), 'Tag': '490805', 'PredefinedType': 'NOTDEFINED'}
# id: 11966
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgc1
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490805
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11954=IfcLocalPlacement(#46,#11953)
# Representation: #11965=IfcProductDefinitionShape($,$,(#11957,#11964))
# Tag: 490805
# PredefinedType: NOTDEFINED
#
#
# {'id': 11988, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgc2', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490806', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11976=IfcLocalPlacement(#46,#11975), 'Representation': #11987=IfcProductDefinitionShape($,$,(#11979,#11986)), 'Tag': '490806', 'PredefinedType': 'NOTDEFINED'}
# id: 11988
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgc2
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490806
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11976=IfcLocalPlacement(#46,#11975)
# Representation: #11987=IfcProductDefinitionShape($,$,(#11979,#11986))
# Tag: 490806
# PredefinedType: NOTDEFINED
#
#
# {'id': 12010, 'type': 'IfcWall', 'GlobalId': '3at$GBZPL3SxpFATHfZgcD', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Бетон_200:490809', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Бетон_200', 'ObjectPlacement': #11998=IfcLocalPlacement(#54,#11997), 'Representation': #12009=IfcProductDefinitionShape($,$,(#12001,#12008)), 'Tag': '490809', 'PredefinedType': 'NOTDEFINED'}
# id: 12010
# type: IfcWall
# GlobalId: 3at$GBZPL3SxpFATHfZgcD
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Бетон_200:490809
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Бетон_200
# ObjectPlacement: #11998=IfcLocalPlacement(#54,#11997)
# Representation: #12009=IfcProductDefinitionShape($,$,(#12001,#12008))
# Tag: 490809
# PredefinedType: NOTDEFINED
#
#
# {'id': 18068, 'type': 'IfcWall', 'GlobalId': '3y00uNPof8qhaDFLl2ZQCk', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160:492580', 'Description': None, 'ObjectType': 'Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160', 'ObjectPlacement': #18053=IfcLocalPlacement(#38,#18052), 'Representation': #18067=IfcProductDefinitionShape($,$,(#18056,#18066)), 'Tag': '492580', 'PredefinedType': 'NOTDEFINED'}
# id: 18068
# type: IfcWall
# GlobalId: 3y00uNPof8qhaDFLl2ZQCk
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160:492580
# Description: None
# ObjectType: Basic Wall:ADSK_Внутренняя_Кирпич120 шт20-шт20_160
# ObjectPlacement: #18053=IfcLocalPlacement(#38,#18052)
# Representation: #18067=IfcProductDefinitionShape($,$,(#18056,#18066))
# Tag: 492580
# PredefinedType: NOTDEFINED
#
#
# {'id': 18561, 'type': 'IfcWall', 'GlobalId': '1qn_HvrIf1nxexJJxrV$Lm', 'OwnerHistory': #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798), 'Name': 'Basic Wall:Базовая - 200мм:494171', 'Description': None, 'ObjectType': 'Basic Wall:Базовая - 200мм', 'ObjectPlacement': #18550=IfcLocalPlacement(#38,#18549), 'Representation': #18560=IfcProductDefinitionShape($,$,(#18553,#18559)), 'Tag': '494171', 'PredefinedType': 'NOTDEFINED'}
# id: 18561
# type: IfcWall
# GlobalId: 1qn_HvrIf1nxexJJxrV$Lm
# OwnerHistory: #18=IfcOwnerHistory(#17,#2,$,.NOCHANGE.,$,$,$,1743448798)
# Name: Basic Wall:Базовая - 200мм:494171
# Description: None
# ObjectType: Basic Wall:Базовая - 200мм
# ObjectPlacement: #18550=IfcLocalPlacement(#38,#18549)
# Representation: #18560=IfcProductDefinitionShape($,$,(#18553,#18559))
# Tag: 494171
# PredefinedType: NOTDEFINED

# %%
el = inspector.get_element("architecture", "doors", 0)

print("📍 Позиция (placement):", inspector.get_coordinates(el))
print("📍 Геометрия (центр):", inspector.get_coordinates_geom(el))
print("📦 Bounding box:", inspector.get_bounding_box(el))
print("🔎 Площадь:", inspector.get_field_value(el, "GrossArea"))
inspector.get_hierarchy(el)
# Out:
# 📍 Позиция (placement): (9900.0, 600.0, 0.0)
# 📍 Геометрия (центр): (9.15, -0.0791489731114339, 0.9896276595746151)
# 📦 Bounding box: {'min': (8.4, -0.16200000000000003, 0.0), 'max': (9.9, 0.0020000000000000018, 2.1), 'size': (1.5, 0.16400000000000003, 2.1)}
# 🔎 Площадь: None
#
# 📂 Иерархия для элемента: AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974
# • IfcDoor — AC_Дверь_Двупольная_Стальная:1460х2080h Н:484974 [GUID: 34MLEKJFT2ifDJcPAg7Kdz]
# • IfcBuildingStorey — Этаж 01 [GUID: 3JdBMZYHv1MPtLo1gvmLGu]
# • IfcBuilding — Наименование здания [GUID: 05P6TmP8X2jg_clMvevcmI]
# • IfcSite — Default [GUID: 05P6TmP8X2jg_clMvevcmH]
# • IfcProject — Номер проекта [GUID: 05P6TmP8X2jg_clMvevcmJ]

# %%
analyzer.list_available()
# Показать все доступные типы элементов
# Out:
# 📚 Доступные категории и типы элементов:
#
# ARCHITECTURE:
#   - spaces
#   - walls
#   - doors
#   - windows
#   - slabs
#   - stairs
#   - railings
#   - coverings
#   - facades
#
# STRUCTURE:
#   - columns
#   - beams
#   - slabs
#   - footings
#
# METAL:
#   - members
#   - plates
#   - columns
#   - beams
